# %% [markdown]
# # 전체적인 코드입니다.

# %% [markdown]
# ## 여기서 중요한 점은 API 요청 제한에 걸리지 않아야 한다는 것입니다.

# %%
# pip install pandas requests

# %%
import pandas as pd
import requests
import gzip
from io import BytesIO
import wikipediaapi
import time
# Out:
# C:\Users\cmhcm\AppData\Local\Temp\ipykernel_14556\436660124.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## 덤프데이터 가져오기

# %%
# 데이터 다운로드 및 추출 함수
def download_pageviews(year, month, day, hour):
    url = f"https://dumps.wikimedia.org/other/pageviews/{year}/{year}-{month:0>2}/pageviews-{year}{month:0>2}{day:0>2}-{hour:0>2}0000.gz"
    response = requests.get(url)
    
    if response.status_code == 200:
        # 파일 형식 확인
        if response.headers.get('Content-Type') == 'application/gzip' or url.endswith('.gz'):
            return response.content
        else:
            raise ValueError("The downloaded file is not a GZIP file.")
    else:
        raise ValueError(f"Failed to download file. Status code: {response.status_code}")

def extract_gz(data):
    with gzip.open(BytesIO(data), 'rb') as f:
        return f.read().decode('utf-8')

def parse_to_dataframe(data):
    lines = data.split('\n')
    records = [line.split() for line in lines if line]
    df = pd.DataFrame(records, columns=['domain_code', 'page_title', 'view_counts', 'another_column'])
    return df

def fetch_pageviews_to_dataframe(year, month, day, hour):
    gz_data = download_pageviews(year, month, day, hour)
    extracted_data = extract_gz(gz_data)
    df = parse_to_dataframe(extracted_data)
    return df

# %% [markdown]
# ## 덤프데이터 정제하기

# %%
def clean_data(df, top_percentage=10):
    # 컬럼명 변경
    df.columns = ['LanguageCode', 'PageTitle', 'PageViews', 'Metadata']
    
    # Metadata 컬럼 DROP
    df.drop(columns=['Metadata'], inplace=True)
    
    # 결측치 처리 및 데이터 타입 변환
    df['PageViews'] = df['PageViews'].fillna(0).astype(int)
    
    # 페이지뷰 기준으로 정렬
    df_sorted = df.sort_values(by='PageViews', ascending=False)
    
    # 상위 top_percentage% 데이터 필터링
    top_n = int(len(df_sorted) * top_percentage / 100)
    df_filtered = df_sorted.head(top_n)
    
    # 제외할 페이지 접두사
    exclude_prefixes = [
        "Main_Page", "Special:", "Talk:", "User:", "User talk:", 
        "Category:", "Portal:", "File:", "Template:", "Help:", "Wikipedia:",
        "MediaWiki:", "Spécial:", "メインページ"
    ]
    df_filtered = df_filtered[~df_filtered['PageTitle'].str.startswith(tuple(exclude_prefixes))]
    
    # 언어 코드 필터링
    language_counts = df_filtered['LanguageCode'].value_counts()
    languages_to_remove = language_counts[language_counts <= 10].index
    df_filtered = df_filtered[~df_filtered['LanguageCode'].isin(languages_to_remove)]
    
    # 나라 딕셔너리 생성
    language_to_country = {
        'en': 'United States', 'ar': 'Saudi Arabia', 'zh': 'China',
        'es': 'Spain', 'fr': 'France', 'de': 'Germany', 'ru': 'Russia',
        'ko': 'Korea', 'ja': 'Japan', 'fa': 'Iran', 'vi': 'Vietnam',
        'he': 'Israel', 'id': 'Indonesia', 'it': 'Italy', 'pl': 'Poland',
        'pt': 'Portugal', 'tl': 'Philippines', 'tr': 'Turkey',
    }
    
    # Country 컬럼 생성
    df_filtered['Country'] = df_filtered['LanguageCode'].str.split('.').str[0].map(language_to_country)
    
    return df_filtered

# %% [markdown]
# ## 3. 위키피디아 API를 통해 요약 정보 추출하기

# %%
# 다양한 언어에 대한 위키피디아 인스턴스를 생성하는 함수
def get_wikipedia_instance(language_code):
    return wikipediaapi.Wikipedia('Brainpedia/1.0 (cmhcms1115@naver.com)', language_code)

# 페이지 제목 리스트에 대해 요약 정보를 가져오는 함수
def fetch_summary_batch(language_code, page_titles):
    wiki_wiki = get_wikipedia_instance(language_code)
    summaries = {}
    for title in page_titles:
        try:
            page = wiki_wiki.page(title)
            summaries[title] = page.summary
        except Exception as e:
            summaries[title] = str(e)  # 에러 발생 시 에러 메시지 저장
    return summaries

# 데이터를 배치로 나누어 요청하고, 요청 후 대기하는 함수
def add_summaries_to_df(df):
    summaries = []
    batch_size = 10
    sleep_time = 4  # 초
    
    # 각 언어 코드에 대해 처리
    for language_code in df['LanguageCode'].unique():
        df_language = df[df['LanguageCode'] == language_code]
        page_titles = df_language['PageTitle'].tolist()
        
        for i in range(0, len(page_titles), batch_size):
            batch_titles = page_titles[i:i + batch_size]
            print(f"Fetching summaries for batch {i // batch_size + 1} in language {language_code}")
            
            batch_summaries = fetch_summary_batch(language_code, batch_titles)
            for title, summary in batch_summaries.items():
                summaries.append({'LanguageCode': language_code, 'PageTitle': title, 'Summary': summary})
            
            time.sleep(sleep_time)  # 배치 요청 후 대기
    
    # DataFrame으로 변환
    summaries_df = pd.DataFrame(summaries)
    df = df.merge(summaries_df, on=['LanguageCode', 'PageTitle'], how='left')
    
    return df

# %%
# 예시 사용
def main(year, month, day, hour):
    # 1. 덤프 데이터 가져오기
    df = fetch_pageviews_to_dataframe(year, month, day, hour)
    
    # 2. 데이터 정제
    df_cleaned = clean_data(df)
    
    # 3. 위키피디아 API를 통해 요약 정보 추가
    df_with_summaries = add_summaries_to_df(df_cleaned)
    
    return df_with_summaries

# 실행 예시
year, month, day, hour = 2024, 7, 31, 1
df_final = main(year, month, day, hour)
print(df_final.head())
# Out:
# Fetching summaries for batch 1 in language en.m
# Fetching summaries for batch 2 in language en.m
# Fetching summaries for batch 3 in language en.m
# Fetching summaries for batch 4 in language en.m
# Fetching summaries for batch 5 in language en.m
# Fetching summaries for batch 6 in language en.m
# Fetching summaries for batch 7 in language en.m
# Fetching summaries for batch 8 in language en.m
# Fetching summaries for batch 9 in language en.m
# Fetching summaries for batch 10 in language en.m
# Fetching summaries for batch 11 in language en.m
# Fetching summaries for batch 12 in language en.m
# Fetching summaries for batch 13 in language en.m
# Fetching summaries for batch 14 in language en.m
# Fetching summaries for batch 15 in language en.m
# Fetching summaries for batch 16 in language en.m
# Fetching summaries for batch 17 in language en.m
# Fetching summaries for batch 18 in language en.m
# Fetching summaries for batch 19 in language en.m
# Fetching summaries for batch 20 in language en.m
# Fetching summaries for batch 21 in language en.m
# Fetching summaries for batch 22 in language en.m
# Fetching summaries for batch 23 in language en.m
# Fetching summaries for batch 24 in language en.m
# Fetching summaries for batch 25 in language en.m
# Fetching summaries for batch 26 in language en.m
# Fetching summaries for batch 27 in language en.m
# Fetching summaries for batch 28 in language en.m
# Fetching summaries for batch 29 in language en.m
# Fetching summaries for batch 30 in language en.m
# Fetching summaries for batch 31 in language en.m
# Fetching summaries for batch 32 in language en.m
# Fetching summaries for batch 33 in language en.m
# Fetching summaries for batch 34 in language en.m
# Fetching summaries for batch 35 in language en.m
# Fetching summaries for batch 36 in language en.m
# Fetching summaries for batch 37 in language en.m
# Fetching summaries for batch 38 in language en.m
# Fetching summaries for batch 39 in language en.m
# Fetching summaries for batch 40 in language en.m
# Fetching summaries for batch 41 in language en.m
# Fetching summaries for batch 42 in language en.m
# Fetching summaries for batch 43 in language en.m
# Fetching summaries for batch 44 in language en.m
# Fetching summaries for batch 45 in language en.m
# Fetching summaries for batch 46 in language en.m
# Fetching summaries for batch 47 in language en.m
# Fetching summaries for batch 48 in language en.m
# Fetching summaries for batch 49 in language en.m
# Fetching summaries for batch 50 in language en.m
# Fetching summaries for batch 51 in language en.m
# Fetching summaries for batch 52 in language en.m
# Fetching summaries for batch 53 in language en.m
# Fetching summaries for batch 54 in language en.m
# Fetching summaries for batch 55 in language en.m
# Fetching summaries for batch 56 in language en.m
# Fetching summaries for batch 57 in language en.m
# Fetching summaries for batch 58 in language en.m
# Fetching summaries for batch 59 in language en.m
# Fetching summaries for batch 60 in language en.m
# Fetching summaries for batch 61 in language en.m
# Fetching summaries for batch 62 in language en.m
# Fetching summaries for batch 63 in language en.m
# Fetching summaries for batch 64 in language en.m
# Fetching summaries for batch 65 in language en.m
# Fetching summaries for batch 66 in language en.m
# Fetching summaries for batch 67 in language en.m
# Fetching summaries for batch 68 in language en.m
# Fetching summaries for batch 69 in language en.m
# Fetching summaries for batch 70 in language en.m
# Fetching summaries for batch 71 in language en.m
# Fetching summaries for batch 72 in language en.m
# Fetching summaries for batch 73 in language en.m
# Fetching summaries for batch 74 in language en.m
# Fetching summaries for batch 75 in language en.m
# Fetching summaries for batch 76 in language en.m
# Fetching summaries for batch 77 in language en.m
# Fetching summaries for batch 78 in language en.m
# Fetching summaries for batch 79 in language en.m
# Fetching summaries for batch 80 in language en.m
# Fetching summaries for batch 81 in language en.m
# Fetching summaries for batch 82 in language en.m
# Fetching summaries for batch 83 in language en.m
# Fetching summaries for batch 84 in language en.m
# Fetching summaries for batch 85 in language en.m
# Fetching summaries for batch 86 in language en.m
# Fetching summaries for batch 87 in language en.m
# Fetching summaries for batch 88 in language en.m
# Fetching summaries for batch 89 in language en.m
# Fetching summaries for batch 90 in language en.m
# Fetching summaries for batch 91 in language en.m
# Fetching summaries for batch 92 in language en.m
# Fetching summaries for batch 93 in language en.m
# Fetching summaries for batch 94 in language en.m
# Fetching summaries for batch 95 in language en.m
# Fetching summaries for batch 96 in language en.m
# Fetching summaries for batch 97 in language en.m
# Fetching summaries for batch 98 in language en.m
# Fetching summaries for batch 99 in language en.m
# Fetching summaries for batch 100 in language en.m
# Fetching summaries for batch 101 in language en.m
# Fetching summaries for batch 102 in language en.m
# Fetching summaries for batch 103 in language en.m
# Fetching summaries for batch 104 in language en.m
# Fetching summaries for batch 105 in language en.m
# Fetching summaries for batch 106 in language en.m
# Fetching summaries for batch 107 in language en.m
# Fetching summaries for batch 108 in language en.m
# Fetching summaries for batch 109 in language en.m
# Fetching summaries for batch 110 in language en.m
# Fetching summaries for batch 111 in language en.m
# Fetching summaries for batch 112 in language en.m
# Fetching summaries for batch 113 in language en.m
# Fetching summaries for batch 114 in language en.m
# Fetching summaries for batch 115 in language en.m
# Fetching summaries for batch 116 in language en.m
# Fetching summaries for batch 117 in language en.m
# Fetching summaries for batch 118 in language en.m
# Fetching summaries for batch 119 in language en.m
# Fetching summaries for batch 120 in language en.m
# Fetching summaries for batch 121 in language en.m
# Fetching summaries for batch 122 in language en.m
# Fetching summaries for batch 123 in language en.m
# Fetching summaries for batch 124 in language en.m
# Fetching summaries for batch 125 in language en.m
# Fetching summaries for batch 126 in language en.m
# Fetching summaries for batch 127 in language en.m
# Fetching summaries for batch 128 in language en.m
# Fetching summaries for batch 129 in language en.m
# Fetching summaries for batch 130 in language en.m
# Fetching summaries for batch 131 in language en.m
# Fetching summaries for batch 132 in language en.m
# Fetching summaries for batch 133 in language en.m
# Fetching summaries for batch 134 in language en.m
# Fetching summaries for batch 135 in language en.m
# Fetching summaries for batch 136 in language en.m
# Fetching summaries for batch 137 in language en.m
# Fetching summaries for batch 138 in language en.m
# Fetching summaries for batch 139 in language en.m
# Fetching summaries for batch 140 in language en.m
# Fetching summaries for batch 141 in language en.m
# Fetching summaries for batch 142 in language en.m
# Fetching summaries for batch 143 in language en.m
# Fetching summaries for batch 144 in language en.m
# Fetching summaries for batch 145 in language en.m
# Fetching summaries for batch 146 in language en.m
# Fetching summaries for batch 147 in language en.m
# Fetching summaries for batch 148 in language en.m
# Fetching summaries for batch 149 in language en.m
# Fetching summaries for batch 150 in language en.m
# Fetching summaries for batch 151 in language en.m
# Fetching summaries for batch 152 in language en.m
# Fetching summaries for batch 153 in language en.m
# Fetching summaries for batch 154 in language en.m
# Fetching summaries for batch 155 in language en.m
# Fetching summaries for batch 156 in language en.m
# Fetching summaries for batch 157 in language en.m
# Fetching summaries for batch 158 in language en.m
# Fetching summaries for batch 159 in language en.m
# Fetching summaries for batch 160 in language en.m
# Fetching summaries for batch 161 in language en.m
# Fetching summaries for batch 162 in language en.m
# Fetching summaries for batch 163 in language en.m
# Fetching summaries for batch 164 in language en.m
# Fetching summaries for batch 165 in language en.m
# Fetching summaries for batch 166 in language en.m
# Fetching summaries for batch 167 in language en.m
# Fetching summaries for batch 168 in language en.m
# Fetching summaries for batch 169 in language en.m
# Fetching summaries for batch 170 in language en.m
# Fetching summaries for batch 171 in language en.m
# Fetching summaries for batch 172 in language en.m
# Fetching summaries for batch 173 in language en.m
# Fetching summaries for batch 174 in language en.m
# Fetching summaries for batch 175 in language en.m
# Fetching summaries for batch 176 in language en.m
# Fetching summaries for batch 177 in language en.m
# Fetching summaries for batch 178 in language en.m
# Fetching summaries for batch 179 in language en.m
# Fetching summaries for batch 180 in language en.m
# Fetching summaries for batch 181 in language en.m
# Fetching summaries for batch 182 in language en.m
# Fetching summaries for batch 183 in language en.m
# Fetching summaries for batch 184 in language en.m
# Fetching summaries for batch 185 in language en.m
# Fetching summaries for batch 186 in language en.m
# Fetching summaries for batch 187 in language en.m
# Fetching summaries for batch 188 in language en.m
# Fetching summaries for batch 189 in language en.m
# Fetching summaries for batch 190 in language en.m
# Fetching summaries for batch 191 in language en.m
# Fetching summaries for batch 192 in language en.m
# Fetching summaries for batch 193 in language en.m
# Fetching summaries for batch 194 in language en.m
# Fetching summaries for batch 195 in language en.m
# Fetching summaries for batch 196 in language en.m
# Fetching summaries for batch 197 in language en.m
# Fetching summaries for batch 198 in language en.m
# Fetching summaries for batch 199 in language en.m
# Fetching summaries for batch 200 in language en.m
# Fetching summaries for batch 201 in language en.m
# Fetching summaries for batch 202 in language en.m
# Fetching summaries for batch 203 in language en.m
# Fetching summaries for batch 204 in language en.m
# Fetching summaries for batch 205 in language en.m
# Fetching summaries for batch 206 in language en.m
# Fetching summaries for batch 207 in language en.m
# Fetching summaries for batch 208 in language en.m
# Fetching summaries for batch 209 in language en.m
# Fetching summaries for batch 210 in language en.m
# Fetching summaries for batch 211 in language en.m
# Fetching summaries for batch 212 in language en.m
# Fetching summaries for batch 213 in language en.m
# Fetching summaries for batch 214 in language en.m
# Fetching summaries for batch 215 in language en.m
# Fetching summaries for batch 216 in language en.m
# Fetching summaries for batch 217 in language en.m
# Fetching summaries for batch 218 in language en.m
# Fetching summaries for batch 219 in language en.m
# Fetching summaries for batch 220 in language en.m
# Fetching summaries for batch 221 in language en.m
# Fetching summaries for batch 222 in language en.m
# Fetching summaries for batch 223 in language en.m
# Fetching summaries for batch 224 in language en.m
# Fetching summaries for batch 225 in language en.m
# Fetching summaries for batch 226 in language en.m
# Fetching summaries for batch 227 in language en.m
# Fetching summaries for batch 228 in language en.m
# Fetching summaries for batch 229 in language en.m
# Fetching summaries for batch 230 in language en.m
# Fetching summaries for batch 231 in language en.m
# Fetching summaries for batch 232 in language en.m
# Fetching summaries for batch 233 in language en.m
# Fetching summaries for batch 234 in language en.m
# Fetching summaries for batch 235 in language en.m
# Fetching summaries for batch 236 in language en.m
# Fetching summaries for batch 237 in language en.m
# Fetching summaries for batch 238 in language en.m
# Fetching summaries for batch 239 in language en.m
# Fetching summaries for batch 240 in language en.m
# Fetching summaries for batch 241 in language en.m
# Fetching summaries for batch 242 in language en.m
# Fetching summaries for batch 243 in language en.m
# Fetching summaries for batch 244 in language en.m
# Fetching summaries for batch 245 in language en.m
# Fetching summaries for batch 246 in language en.m
# Fetching summaries for batch 247 in language en.m
# Fetching summaries for batch 248 in language en.m
# Fetching summaries for batch 249 in language en.m
# Fetching summaries for batch 250 in language en.m
# Fetching summaries for batch 251 in language en.m
# Fetching summaries for batch 252 in language en.m
# Fetching summaries for batch 253 in language en.m
# Fetching summaries for batch 254 in language en.m
# Fetching summaries for batch 255 in language en.m
# Fetching summaries for batch 256 in language en.m
# Fetching summaries for batch 257 in language en.m
# Fetching summaries for batch 258 in language en.m
# Fetching summaries for batch 259 in language en.m
# Fetching summaries for batch 260 in language en.m
# Fetching summaries for batch 261 in language en.m
# Fetching summaries for batch 262 in language en.m
# Fetching summaries for batch 263 in language en.m
# Fetching summaries for batch 264 in language en.m
# Fetching summaries for batch 265 in language en.m
# Fetching summaries for batch 266 in language en.m
# Fetching summaries for batch 267 in language en.m
# Fetching summaries for batch 268 in language en.m
# Fetching summaries for batch 269 in language en.m
# Fetching summaries for batch 270 in language en.m
# Fetching summaries for batch 271 in language en.m
# Fetching summaries for batch 272 in language en.m
# Fetching summaries for batch 273 in language en.m
# Fetching summaries for batch 274 in language en.m
# Fetching summaries for batch 275 in language en.m
# Fetching summaries for batch 276 in language en.m
# Fetching summaries for batch 277 in language en.m
# Fetching summaries for batch 278 in language en.m
# Fetching summaries for batch 279 in language en.m
# Fetching summaries for batch 280 in language en.m
# Fetching summaries for batch 281 in language en.m
# Fetching summaries for batch 282 in language en.m
# Fetching summaries for batch 283 in language en.m
# Fetching summaries for batch 284 in language en.m
# Fetching summaries for batch 285 in language en.m
# Fetching summaries for batch 286 in language en.m
# Fetching summaries for batch 287 in language en.m
# Fetching summaries for batch 288 in language en.m
# Fetching summaries for batch 289 in language en.m
# Fetching summaries for batch 290 in language en.m
# Fetching summaries for batch 291 in language en.m
# Fetching summaries for batch 292 in language en.m
# Fetching summaries for batch 293 in language en.m
# Fetching summaries for batch 294 in language en.m
# Fetching summaries for batch 295 in language en.m
# Fetching summaries for batch 296 in language en.m
# Fetching summaries for batch 297 in language en.m
# Fetching summaries for batch 298 in language en.m
# Fetching summaries for batch 299 in language en.m
# Fetching summaries for batch 300 in language en.m
# Fetching summaries for batch 301 in language en.m
# Fetching summaries for batch 302 in language en.m
# Fetching summaries for batch 303 in language en.m
# Fetching summaries for batch 304 in language en.m
# Fetching summaries for batch 305 in language en.m
# Fetching summaries for batch 306 in language en.m
# Fetching summaries for batch 307 in language en.m
# Fetching summaries for batch 308 in language en.m
# Fetching summaries for batch 309 in language en.m
# Fetching summaries for batch 310 in language en.m
# Fetching summaries for batch 311 in language en.m
# Fetching summaries for batch 312 in language en.m
# Fetching summaries for batch 313 in language en.m
# Fetching summaries for batch 314 in language en.m
# Fetching summaries for batch 315 in language en.m
# Fetching summaries for batch 316 in language en.m
# Fetching summaries for batch 317 in language en.m
# Fetching summaries for batch 318 in language en.m
# Fetching summaries for batch 319 in language en.m
# Fetching summaries for batch 320 in language en.m
# Fetching summaries for batch 321 in language en.m
# Fetching summaries for batch 322 in language en.m
# Fetching summaries for batch 323 in language en.m
# Fetching summaries for batch 324 in language en.m
# Fetching summaries for batch 325 in language en.m
# Fetching summaries for batch 326 in language en.m
# Fetching summaries for batch 327 in language en.m
# Fetching summaries for batch 328 in language en.m
# Fetching summaries for batch 329 in language en.m
# Fetching summaries for batch 330 in language en.m
# Fetching summaries for batch 331 in language en.m
# Fetching summaries for batch 332 in language en.m
# Fetching summaries for batch 333 in language en.m
# Fetching summaries for batch 334 in language en.m
# Fetching summaries for batch 335 in language en.m
# Fetching summaries for batch 336 in language en.m
# Fetching summaries for batch 337 in language en.m
# Fetching summaries for batch 338 in language en.m
# Fetching summaries for batch 339 in language en.m
# Fetching summaries for batch 340 in language en.m
# Fetching summaries for batch 341 in language en.m
# Fetching summaries for batch 342 in language en.m
# Fetching summaries for batch 343 in language en.m
# Fetching summaries for batch 344 in language en.m
# Fetching summaries for batch 345 in language en.m
# Fetching summaries for batch 346 in language en.m
# Fetching summaries for batch 347 in language en.m
# Fetching summaries for batch 348 in language en.m
# Fetching summaries for batch 349 in language en.m
# Fetching summaries for batch 350 in language en.m
# Fetching summaries for batch 351 in language en.m
# Fetching summaries for batch 352 in language en.m
# Fetching summaries for batch 353 in language en.m
# Fetching summaries for batch 354 in language en.m
# Fetching summaries for batch 355 in language en.m
# Fetching summaries for batch 356 in language en.m
# Fetching summaries for batch 357 in language en.m
# Fetching summaries for batch 358 in language en.m
# Fetching summaries for batch 359 in language en.m
# Fetching summaries for batch 360 in language en.m
# Fetching summaries for batch 361 in language en.m
# Fetching summaries for batch 362 in language en.m
# Fetching summaries for batch 363 in language en.m
# Fetching summaries for batch 364 in language en.m
# Fetching summaries for batch 365 in language en.m
# Fetching summaries for batch 366 in language en.m
# Fetching summaries for batch 367 in language en.m
# Fetching summaries for batch 368 in language en.m
# Fetching summaries for batch 369 in language en.m
# Fetching summaries for batch 370 in language en.m
# Fetching summaries for batch 371 in language en.m
# Fetching summaries for batch 372 in language en.m
# Fetching summaries for batch 373 in language en.m
# Fetching summaries for batch 374 in language en.m
# Fetching summaries for batch 375 in language en.m
# Fetching summaries for batch 376 in language en.m
# Fetching summaries for batch 377 in language en.m
# Fetching summaries for batch 378 in language en.m
# Fetching summaries for batch 379 in language en.m
# Fetching summaries for batch 380 in language en.m
# Fetching summaries for batch 381 in language en.m
# Fetching summaries for batch 382 in language en.m
# Fetching summaries for batch 383 in language en.m
# Fetching summaries for batch 384 in language en.m
# Fetching summaries for batch 385 in language en.m
# Fetching summaries for batch 386 in language en.m
# Fetching summaries for batch 387 in language en.m
# Fetching summaries for batch 388 in language en.m
# Fetching summaries for batch 389 in language en.m
# Fetching summaries for batch 390 in language en.m
# Fetching summaries for batch 391 in language en.m
# Fetching summaries for batch 392 in language en.m
# Fetching summaries for batch 393 in language en.m
# Fetching summaries for batch 394 in language en.m
# Fetching summaries for batch 395 in language en.m
# Fetching summaries for batch 396 in language en.m
# Fetching summaries for batch 397 in language en.m
# Fetching summaries for batch 398 in language en.m
# Fetching summaries for batch 399 in language en.m
# Fetching summaries for batch 400 in language en.m
# Fetching summaries for batch 401 in language en.m
# Fetching summaries for batch 402 in language en.m
# Fetching summaries for batch 403 in language en.m
# Fetching summaries for batch 404 in language en.m
# Fetching summaries for batch 405 in language en.m
# Fetching summaries for batch 406 in language en.m
# Fetching summaries for batch 407 in language en.m
# Fetching summaries for batch 408 in language en.m
# Fetching summaries for batch 409 in language en.m
# Fetching summaries for batch 410 in language en.m
# Fetching summaries for batch 411 in language en.m
# Fetching summaries for batch 412 in language en.m
# Fetching summaries for batch 413 in language en.m
# Fetching summaries for batch 414 in language en.m
# Fetching summaries for batch 415 in language en.m
# Fetching summaries for batch 416 in language en.m
# Fetching summaries for batch 417 in language en.m
# Fetching summaries for batch 418 in language en.m
# Fetching summaries for batch 419 in language en.m
# Fetching summaries for batch 420 in language en.m
# Fetching summaries for batch 421 in language en.m
# Fetching summaries for batch 422 in language en.m
# Fetching summaries for batch 423 in language en.m
# Fetching summaries for batch 424 in language en.m
# Fetching summaries for batch 425 in language en.m
# Fetching summaries for batch 426 in language en.m
# Fetching summaries for batch 427 in language en.m
# Fetching summaries for batch 428 in language en.m
# Fetching summaries for batch 429 in language en.m
# Fetching summaries for batch 430 in language en.m
# Fetching summaries for batch 431 in language en.m
# Fetching summaries for batch 432 in language en.m
# Fetching summaries for batch 433 in language en.m
# Fetching summaries for batch 434 in language en.m
# Fetching summaries for batch 435 in language en.m
# Fetching summaries for batch 436 in language en.m
# Fetching summaries for batch 437 in language en.m
# Fetching summaries for batch 438 in language en.m
# Fetching summaries for batch 439 in language en.m
# Fetching summaries for batch 440 in language en.m
# Fetching summaries for batch 441 in language en.m
# Fetching summaries for batch 442 in language en.m
# Fetching summaries for batch 443 in language en.m
# Fetching summaries for batch 444 in language en.m
# Fetching summaries for batch 445 in language en.m
# Fetching summaries for batch 446 in language en.m
# Fetching summaries for batch 447 in language en.m
# Fetching summaries for batch 448 in language en.m
# Fetching summaries for batch 449 in language en.m
# Fetching summaries for batch 450 in language en.m
# Fetching summaries for batch 451 in language en.m
# Fetching summaries for batch 452 in language en.m
# Fetching summaries for batch 453 in language en.m
# Fetching summaries for batch 454 in language en.m
# Fetching summaries for batch 455 in language en.m
# Fetching summaries for batch 456 in language en.m
# Fetching summaries for batch 457 in language en.m
# Fetching summaries for batch 458 in language en.m
# Fetching summaries for batch 459 in language en.m
# Fetching summaries for batch 460 in language en.m
# Fetching summaries for batch 461 in language en.m
# Fetching summaries for batch 462 in language en.m
# Fetching summaries for batch 463 in language en.m
# Fetching summaries for batch 464 in language en.m
# Fetching summaries for batch 465 in language en.m
# Fetching summaries for batch 466 in language en.m
# Fetching summaries for batch 467 in language en.m
# Fetching summaries for batch 468 in language en.m
# Fetching summaries for batch 469 in language en.m
# Fetching summaries for batch 470 in language en.m
# Fetching summaries for batch 471 in language en.m
# Fetching summaries for batch 472 in language en.m
# Fetching summaries for batch 473 in language en.m
# Fetching summaries for batch 474 in language en.m
# Fetching summaries for batch 475 in language en.m
# Fetching summaries for batch 476 in language en.m
# Fetching summaries for batch 477 in language en.m
# Fetching summaries for batch 478 in language en.m
# Fetching summaries for batch 479 in language en.m
# Fetching summaries for batch 480 in language en.m
# Fetching summaries for batch 481 in language en.m
# Fetching summaries for batch 482 in language en.m
# Fetching summaries for batch 483 in language en.m
# Fetching summaries for batch 484 in language en.m
# Fetching summaries for batch 485 in language en.m
# Fetching summaries for batch 486 in language en.m
# Fetching summaries for batch 487 in language en.m
# Fetching summaries for batch 488 in language en.m
# Fetching summaries for batch 489 in language en.m
# Fetching summaries for batch 490 in language en.m
# Fetching summaries for batch 491 in language en.m
# Fetching summaries for batch 492 in language en.m
# Fetching summaries for batch 493 in language en.m
# Fetching summaries for batch 494 in language en.m
# Fetching summaries for batch 495 in language en.m
# Fetching summaries for batch 496 in language en.m
# Fetching summaries for batch 497 in language en.m
# Fetching summaries for batch 498 in language en.m
# Fetching summaries for batch 499 in language en.m
# Fetching summaries for batch 500 in language en.m
# Fetching summaries for batch 501 in language en.m
# Fetching summaries for batch 502 in language en.m
# Fetching summaries for batch 503 in language en.m
# Fetching summaries for batch 504 in language en.m
# Fetching summaries for batch 505 in language en.m
# Fetching summaries for batch 506 in language en.m
# Fetching summaries for batch 507 in language en.m
# Fetching summaries for batch 508 in language en.m
# Fetching summaries for batch 509 in language en.m
# Fetching summaries for batch 510 in language en.m
# Fetching summaries for batch 511 in language en.m
# Fetching summaries for batch 512 in language en.m
# Fetching summaries for batch 513 in language en.m
# Fetching summaries for batch 514 in language en.m
# Fetching summaries for batch 515 in language en.m
# Fetching summaries for batch 516 in language en.m
# Fetching summaries for batch 517 in language en.m
# Fetching summaries for batch 518 in language en.m
# Fetching summaries for batch 519 in language en.m
# Fetching summaries for batch 520 in language en.m
# Fetching summaries for batch 521 in language en.m
# Fetching summaries for batch 522 in language en.m
# Fetching summaries for batch 523 in language en.m
# Fetching summaries for batch 524 in language en.m
# Fetching summaries for batch 525 in language en.m
# Fetching summaries for batch 526 in language en.m
# Fetching summaries for batch 527 in language en.m
# Fetching summaries for batch 528 in language en.m
# Fetching summaries for batch 529 in language en.m
# Fetching summaries for batch 530 in language en.m
# Fetching summaries for batch 531 in language en.m
# Fetching summaries for batch 532 in language en.m
# Fetching summaries for batch 533 in language en.m
# Fetching summaries for batch 534 in language en.m
# Fetching summaries for batch 535 in language en.m
# Fetching summaries for batch 536 in language en.m
# Fetching summaries for batch 537 in language en.m
# Fetching summaries for batch 538 in language en.m
# Fetching summaries for batch 539 in language en.m
# Fetching summaries for batch 540 in language en.m
# Fetching summaries for batch 541 in language en.m
# Fetching summaries for batch 542 in language en.m
# Fetching summaries for batch 543 in language en.m
# Fetching summaries for batch 544 in language en.m
# Fetching summaries for batch 545 in language en.m
# Fetching summaries for batch 546 in language en.m
# Fetching summaries for batch 547 in language en.m
# Fetching summaries for batch 548 in language en.m
# Fetching summaries for batch 549 in language en.m
# Fetching summaries for batch 550 in language en.m
# Fetching summaries for batch 551 in language en.m
# Fetching summaries for batch 552 in language en.m
# Fetching summaries for batch 553 in language en.m
# Fetching summaries for batch 554 in language en.m
# Fetching summaries for batch 555 in language en.m
# Fetching summaries for batch 556 in language en.m
# Fetching summaries for batch 557 in language en.m
# Fetching summaries for batch 558 in language en.m
# Fetching summaries for batch 559 in language en.m
# Fetching summaries for batch 560 in language en.m
# Fetching summaries for batch 561 in language en.m
# Fetching summaries for batch 562 in language en.m
# Fetching summaries for batch 563 in language en.m
# Fetching summaries for batch 564 in language en.m
# Fetching summaries for batch 565 in language en.m
# Fetching summaries for batch 566 in language en.m
# Fetching summaries for batch 567 in language en.m
# Fetching summaries for batch 568 in language en.m
# Fetching summaries for batch 569 in language en.m
# Fetching summaries for batch 570 in language en.m
# Fetching summaries for batch 571 in language en.m
# Fetching summaries for batch 572 in language en.m
# Fetching summaries for batch 573 in language en.m
# Fetching summaries for batch 574 in language en.m
# Fetching summaries for batch 575 in language en.m
# Fetching summaries for batch 576 in language en.m
# Fetching summaries for batch 577 in language en.m
# Fetching summaries for batch 578 in language en.m
# Fetching summaries for batch 579 in language en.m
# Fetching summaries for batch 580 in language en.m
# Fetching summaries for batch 581 in language en.m
# Fetching summaries for batch 582 in language en.m
# Fetching summaries for batch 583 in language en.m
# Fetching summaries for batch 584 in language en.m
# Fetching summaries for batch 585 in language en.m
# Fetching summaries for batch 586 in language en.m
# Fetching summaries for batch 587 in language en.m
# Fetching summaries for batch 588 in language en.m
# Fetching summaries for batch 589 in language en.m
# Fetching summaries for batch 590 in language en.m
# Fetching summaries for batch 591 in language en.m
# Fetching summaries for batch 592 in language en.m
# Fetching summaries for batch 593 in language en.m
# Fetching summaries for batch 594 in language en.m
# Fetching summaries for batch 595 in language en.m
# Fetching summaries for batch 596 in language en.m
# Fetching summaries for batch 597 in language en.m
# Fetching summaries for batch 598 in language en.m
# Fetching summaries for batch 599 in language en.m
# Fetching summaries for batch 600 in language en.m
# Fetching summaries for batch 601 in language en.m
# Fetching summaries for batch 602 in language en.m
# Fetching summaries for batch 603 in language en.m
# Fetching summaries for batch 604 in language en.m
# Fetching summaries for batch 605 in language en.m
# Fetching summaries for batch 606 in language en.m
# Fetching summaries for batch 607 in language en.m
# Fetching summaries for batch 608 in language en.m
# Fetching summaries for batch 609 in language en.m
# Fetching summaries for batch 610 in language en.m
# Fetching summaries for batch 611 in language en.m
# Fetching summaries for batch 612 in language en.m
# Fetching summaries for batch 613 in language en.m
# Fetching summaries for batch 614 in language en.m
# Fetching summaries for batch 615 in language en.m
# Fetching summaries for batch 616 in language en.m
# Fetching summaries for batch 617 in language en.m
# Fetching summaries for batch 618 in language en.m
# Fetching summaries for batch 619 in language en.m
# Fetching summaries for batch 620 in language en.m
# Fetching summaries for batch 621 in language en.m
# Fetching summaries for batch 622 in language en.m
# Fetching summaries for batch 623 in language en.m
# Fetching summaries for batch 624 in language en.m
# Fetching summaries for batch 625 in language en.m
# Fetching summaries for batch 626 in language en.m
# Fetching summaries for batch 627 in language en.m
# Fetching summaries for batch 628 in language en.m
# Fetching summaries for batch 629 in language en.m
# Fetching summaries for batch 630 in language en.m
# Fetching summaries for batch 631 in language en.m
# Fetching summaries for batch 632 in language en.m
# Fetching summaries for batch 633 in language en.m
# Fetching summaries for batch 634 in language en.m
# Fetching summaries for batch 635 in language en.m
# Fetching summaries for batch 636 in language en.m
# Fetching summaries for batch 637 in language en.m
# Fetching summaries for batch 638 in language en.m
# Fetching summaries for batch 639 in language en.m
# Fetching summaries for batch 640 in language en.m
# Fetching summaries for batch 641 in language en.m
# Fetching summaries for batch 642 in language en.m
# Fetching summaries for batch 643 in language en.m
# Fetching summaries for batch 644 in language en.m
# Fetching summaries for batch 645 in language en.m
# Fetching summaries for batch 646 in language en.m
# Fetching summaries for batch 647 in language en.m
# Fetching summaries for batch 648 in language en.m
# Fetching summaries for batch 649 in language en.m
# Fetching summaries for batch 650 in language en.m
# Fetching summaries for batch 651 in language en.m
# Fetching summaries for batch 652 in language en.m
# Fetching summaries for batch 653 in language en.m
# Fetching summaries for batch 654 in language en.m
# Fetching summaries for batch 655 in language en.m
# Fetching summaries for batch 656 in language en.m
# Fetching summaries for batch 657 in language en.m
# Fetching summaries for batch 658 in language en.m
# Fetching summaries for batch 659 in language en.m
# Fetching summaries for batch 660 in language en.m
# Fetching summaries for batch 661 in language en.m
# Fetching summaries for batch 662 in language en.m
# Fetching summaries for batch 663 in language en.m
# Fetching summaries for batch 664 in language en.m
# Fetching summaries for batch 665 in language en.m
# Fetching summaries for batch 666 in language en.m
# Fetching summaries for batch 667 in language en.m
# Fetching summaries for batch 668 in language en.m
# Fetching summaries for batch 669 in language en.m
# Fetching summaries for batch 670 in language en.m
# Fetching summaries for batch 671 in language en.m
# Fetching summaries for batch 672 in language en.m
# Fetching summaries for batch 673 in language en.m
# Fetching summaries for batch 674 in language en.m
# Fetching summaries for batch 675 in language en.m
# Fetching summaries for batch 676 in language en.m
# Fetching summaries for batch 677 in language en.m
# Fetching summaries for batch 678 in language en.m
# Fetching summaries for batch 679 in language en.m
# Fetching summaries for batch 680 in language en.m
# Fetching summaries for batch 681 in language en.m
# Fetching summaries for batch 682 in language en.m
# Fetching summaries for batch 683 in language en.m
# Fetching summaries for batch 684 in language en.m
# Fetching summaries for batch 685 in language en.m
# Fetching summaries for batch 686 in language en.m
# Fetching summaries for batch 687 in language en.m
# Fetching summaries for batch 688 in language en.m
# Fetching summaries for batch 689 in language en.m
# Fetching summaries for batch 690 in language en.m
# Fetching summaries for batch 691 in language en.m
# Fetching summaries for batch 692 in language en.m
# Fetching summaries for batch 693 in language en.m
# Fetching summaries for batch 694 in language en.m
# Fetching summaries for batch 695 in language en.m
# Fetching summaries for batch 696 in language en.m
# Fetching summaries for batch 697 in language en.m
# Fetching summaries for batch 698 in language en.m
# Fetching summaries for batch 699 in language en.m
# Fetching summaries for batch 700 in language en.m
# Fetching summaries for batch 701 in language en.m
# Fetching summaries for batch 702 in language en.m
# Fetching summaries for batch 703 in language en.m
# Fetching summaries for batch 704 in language en.m
# Fetching summaries for batch 705 in language en.m
# Fetching summaries for batch 706 in language en.m
# Fetching summaries for batch 707 in language en.m
# Fetching summaries for batch 708 in language en.m
# Fetching summaries for batch 709 in language en.m
# Fetching summaries for batch 710 in language en.m
# Fetching summaries for batch 711 in language en.m
# Fetching summaries for batch 712 in language en.m
# Fetching summaries for batch 713 in language en.m
# Fetching summaries for batch 714 in language en.m
# Fetching summaries for batch 715 in language en.m
# Fetching summaries for batch 716 in language en.m
# Fetching summaries for batch 717 in language en.m
# Fetching summaries for batch 718 in language en.m
# Fetching summaries for batch 719 in language en.m
# Fetching summaries for batch 720 in language en.m
# Fetching summaries for batch 721 in language en.m
# Fetching summaries for batch 722 in language en.m
# Fetching summaries for batch 723 in language en.m
# Fetching summaries for batch 724 in language en.m
# Fetching summaries for batch 725 in language en.m
# Fetching summaries for batch 726 in language en.m
# Fetching summaries for batch 727 in language en.m
# Fetching summaries for batch 728 in language en.m
# Fetching summaries for batch 729 in language en.m
# Fetching summaries for batch 730 in language en.m
# Fetching summaries for batch 731 in language en.m
# Fetching summaries for batch 732 in language en.m
# Fetching summaries for batch 733 in language en.m
# Fetching summaries for batch 734 in language en.m
# Fetching summaries for batch 735 in language en.m
# Fetching summaries for batch 736 in language en.m
# Fetching summaries for batch 737 in language en.m
# Fetching summaries for batch 738 in language en.m
# Fetching summaries for batch 739 in language en.m
# Fetching summaries for batch 740 in language en.m
# Fetching summaries for batch 741 in language en.m
# Fetching summaries for batch 742 in language en.m
# Fetching summaries for batch 743 in language en.m
# Fetching summaries for batch 744 in language en.m
# Fetching summaries for batch 745 in language en.m
# Fetching summaries for batch 746 in language en.m
# Fetching summaries for batch 747 in language en.m
# Fetching summaries for batch 748 in language en.m
# Fetching summaries for batch 749 in language en.m
# Fetching summaries for batch 750 in language en.m
# Fetching summaries for batch 751 in language en.m
# Fetching summaries for batch 752 in language en.m
# Fetching summaries for batch 753 in language en.m
# Fetching summaries for batch 754 in language en.m
# Fetching summaries for batch 755 in language en.m
# Fetching summaries for batch 756 in language en.m
# Fetching summaries for batch 757 in language en.m
# Fetching summaries for batch 758 in language en.m
# Fetching summaries for batch 759 in language en.m
# Fetching summaries for batch 760 in language en.m
# Fetching summaries for batch 761 in language en.m
# Fetching summaries for batch 762 in language en.m
# Fetching summaries for batch 763 in language en.m
# Fetching summaries for batch 764 in language en.m
# Fetching summaries for batch 765 in language en.m
# Fetching summaries for batch 766 in language en.m
# Fetching summaries for batch 767 in language en.m
# Fetching summaries for batch 768 in language en.m
# Fetching summaries for batch 769 in language en.m
# Fetching summaries for batch 770 in language en.m
# Fetching summaries for batch 771 in language en.m
# Fetching summaries for batch 772 in language en.m
# Fetching summaries for batch 773 in language en.m
# Fetching summaries for batch 774 in language en.m
# Fetching summaries for batch 775 in language en.m
# Fetching summaries for batch 776 in language en.m
# Fetching summaries for batch 777 in language en.m
# Fetching summaries for batch 778 in language en.m
# Fetching summaries for batch 779 in language en.m
# Fetching summaries for batch 780 in language en.m
# Fetching summaries for batch 781 in language en.m
# Fetching summaries for batch 782 in language en.m
# Fetching summaries for batch 783 in language en.m
# Fetching summaries for batch 784 in language en.m
# Fetching summaries for batch 785 in language en.m
# Fetching summaries for batch 786 in language en.m
# Fetching summaries for batch 787 in language en.m
# Fetching summaries for batch 788 in language en.m
# Fetching summaries for batch 789 in language en.m
# Fetching summaries for batch 790 in language en.m
# Fetching summaries for batch 791 in language en.m
# Fetching summaries for batch 792 in language en.m
# Fetching summaries for batch 793 in language en.m
# Fetching summaries for batch 794 in language en.m
# Fetching summaries for batch 795 in language en.m
# Fetching summaries for batch 796 in language en.m
# Fetching summaries for batch 797 in language en.m
# Fetching summaries for batch 798 in language en.m
# Fetching summaries for batch 799 in language en.m
# Fetching summaries for batch 800 in language en.m
# Fetching summaries for batch 801 in language en.m
# Fetching summaries for batch 802 in language en.m
# Fetching summaries for batch 803 in language en.m
# Fetching summaries for batch 804 in language en.m
# Fetching summaries for batch 805 in language en.m
# Fetching summaries for batch 806 in language en.m
# Fetching summaries for batch 807 in language en.m
# Fetching summaries for batch 808 in language en.m
# Fetching summaries for batch 809 in language en.m
# Fetching summaries for batch 810 in language en.m
# Fetching summaries for batch 811 in language en.m
# Fetching summaries for batch 812 in language en.m
# Fetching summaries for batch 813 in language en.m
# Fetching summaries for batch 814 in language en.m
# Fetching summaries for batch 815 in language en.m
# Fetching summaries for batch 816 in language en.m
# Fetching summaries for batch 817 in language en.m
# Fetching summaries for batch 818 in language en.m
# Fetching summaries for batch 819 in language en.m
# Fetching summaries for batch 820 in language en.m
# Fetching summaries for batch 821 in language en.m
# Fetching summaries for batch 822 in language en.m
# Fetching summaries for batch 823 in language en.m
# Fetching summaries for batch 824 in language en.m
# Fetching summaries for batch 825 in language en.m
# Fetching summaries for batch 826 in language en.m
# Fetching summaries for batch 827 in language en.m
# Fetching summaries for batch 828 in language en.m
# Fetching summaries for batch 829 in language en.m
# Fetching summaries for batch 830 in language en.m
# Fetching summaries for batch 831 in language en.m
# Fetching summaries for batch 832 in language en.m
# Fetching summaries for batch 833 in language en.m
# Fetching summaries for batch 834 in language en.m
# Fetching summaries for batch 835 in language en.m
# Fetching summaries for batch 836 in language en.m
# Fetching summaries for batch 837 in language en.m
# Fetching summaries for batch 838 in language en.m
# Fetching summaries for batch 839 in language en.m
# Fetching summaries for batch 840 in language en.m
# Fetching summaries for batch 841 in language en.m
# Fetching summaries for batch 842 in language en.m
# Fetching summaries for batch 843 in language en.m
# Fetching summaries for batch 844 in language en.m
# Fetching summaries for batch 845 in language en.m
# Fetching summaries for batch 846 in language en.m
# Fetching summaries for batch 847 in language en.m
# Fetching summaries for batch 848 in language en.m
# Fetching summaries for batch 849 in language en.m
# Fetching summaries for batch 850 in language en.m
# Fetching summaries for batch 851 in language en.m
# Fetching summaries for batch 852 in language en.m
# Fetching summaries for batch 853 in language en.m
# Fetching summaries for batch 854 in language en.m
# Fetching summaries for batch 855 in language en.m
# Fetching summaries for batch 856 in language en.m
# Fetching summaries for batch 857 in language en.m
# Fetching summaries for batch 858 in language en.m
# Fetching summaries for batch 859 in language en.m
# Fetching summaries for batch 860 in language en.m
# Fetching summaries for batch 861 in language en.m
# Fetching summaries for batch 862 in language en.m
# Fetching summaries for batch 863 in language en.m
# Fetching summaries for batch 864 in language en.m
# Fetching summaries for batch 865 in language en.m
# Fetching summaries for batch 866 in language en.m
# Fetching summaries for batch 867 in language en.m
# Fetching summaries for batch 868 in language en.m
# Fetching summaries for batch 869 in language en.m
# Fetching summaries for batch 870 in language en.m
# Fetching summaries for batch 871 in language en.m
# Fetching summaries for batch 872 in language en.m
# Fetching summaries for batch 873 in language en.m
# Fetching summaries for batch 874 in language en.m
# Fetching summaries for batch 875 in language en.m
# Fetching summaries for batch 876 in language en.m
# Fetching summaries for batch 877 in language en.m
# Fetching summaries for batch 878 in language en.m
# Fetching summaries for batch 879 in language en.m
# Fetching summaries for batch 880 in language en.m
# Fetching summaries for batch 881 in language en.m
# Fetching summaries for batch 882 in language en.m
# Fetching summaries for batch 883 in language en.m
# Fetching summaries for batch 884 in language en.m
# Fetching summaries for batch 885 in language en.m
# Fetching summaries for batch 886 in language en.m
# Fetching summaries for batch 887 in language en.m
# Fetching summaries for batch 888 in language en.m
# Fetching summaries for batch 889 in language en.m
# Fetching summaries for batch 890 in language en.m
# Fetching summaries for batch 891 in language en.m
# Fetching summaries for batch 892 in language en.m
# Fetching summaries for batch 893 in language en.m
# Fetching summaries for batch 894 in language en.m
# Fetching summaries for batch 895 in language en.m
# Fetching summaries for batch 896 in language en.m
# Fetching summaries for batch 897 in language en.m
# Fetching summaries for batch 898 in language en.m
# Fetching summaries for batch 899 in language en.m
# Fetching summaries for batch 900 in language en.m
# Fetching summaries for batch 901 in language en.m
# Fetching summaries for batch 902 in language en.m
# Fetching summaries for batch 903 in language en.m
# Fetching summaries for batch 904 in language en.m
# Fetching summaries for batch 905 in language en.m
# Fetching summaries for batch 906 in language en.m
# Fetching summaries for batch 907 in language en.m
# Fetching summaries for batch 908 in language en.m
# Fetching summaries for batch 909 in language en.m
# Fetching summaries for batch 910 in language en.m
# Fetching summaries for batch 911 in language en.m
# Fetching summaries for batch 912 in language en.m
# Fetching summaries for batch 913 in language en.m
# Fetching summaries for batch 914 in language en.m
# Fetching summaries for batch 915 in language en.m
# Fetching summaries for batch 916 in language en.m
# Fetching summaries for batch 917 in language en.m
# Fetching summaries for batch 918 in language en.m
# Fetching summaries for batch 919 in language en.m
# Fetching summaries for batch 920 in language en.m
# Fetching summaries for batch 921 in language en.m
# Fetching summaries for batch 922 in language en.m
# Fetching summaries for batch 923 in language en.m
# Fetching summaries for batch 924 in language en.m
# Fetching summaries for batch 925 in language en.m
# Fetching summaries for batch 926 in language en.m
# Fetching summaries for batch 927 in language en.m
# Fetching summaries for batch 928 in language en.m
# Fetching summaries for batch 929 in language en.m
# Fetching summaries for batch 930 in language en.m
# Fetching summaries for batch 931 in language en.m
# Fetching summaries for batch 932 in language en.m
# Fetching summaries for batch 933 in language en.m
# Fetching summaries for batch 934 in language en.m
# Fetching summaries for batch 935 in language en.m
# Fetching summaries for batch 936 in language en.m
# Fetching summaries for batch 937 in language en.m
# Fetching summaries for batch 938 in language en.m
# Fetching summaries for batch 939 in language en.m
# Fetching summaries for batch 940 in language en.m
# Fetching summaries for batch 941 in language en.m
# Fetching summaries for batch 942 in language en.m
# Fetching summaries for batch 943 in language en.m
# Fetching summaries for batch 944 in language en.m
# Fetching summaries for batch 945 in language en.m
# Fetching summaries for batch 946 in language en.m
# Fetching summaries for batch 947 in language en.m
# Fetching summaries for batch 948 in language en.m
# Fetching summaries for batch 949 in language en.m
# Fetching summaries for batch 950 in language en.m
# Fetching summaries for batch 951 in language en.m
# Fetching summaries for batch 952 in language en.m
# Fetching summaries for batch 953 in language en.m
# Fetching summaries for batch 954 in language en.m
# Fetching summaries for batch 955 in language en.m
# Fetching summaries for batch 956 in language en.m
# Fetching summaries for batch 957 in language en.m
# Fetching summaries for batch 958 in language en.m
# Fetching summaries for batch 959 in language en.m
# Fetching summaries for batch 960 in language en.m
# Fetching summaries for batch 961 in language en.m
# Fetching summaries for batch 962 in language en.m
# ...
# Fetching summaries for batch 2086 in language en.m
# Fetching summaries for batch 2087 in language en.m
# Fetching summaries for batch 2088 in language en.m
# Fetching summaries for batch 2089 in language en.m
# Fetching summaries for batch 2090 in language en.m
# Fetching summaries for batch 2091 in language en.m
# Fetching summaries for batch 2092 in language en.m
# Fetching summaries for batch 2093 in language en.m
# Fetching summaries for batch 2094 in language en.m
# Fetching summaries for batch 2095 in language en.m
# Fetching summaries for batch 2096 in language en.m
# Fetching summaries for batch 2097 in language en.m
# Fetching summaries for batch 2098 in language en.m
# Fetching summaries for batch 2099 in language en.m
# Fetching summaries for batch 2100 in language en.m
# Fetching summaries for batch 2101 in language en.m
# Fetching summaries for batch 2102 in language en.m
# Fetching summaries for batch 2103 in language en.m
# Fetching summaries for batch 2104 in language en.m
# Fetching summaries for batch 2105 in language en.m
# Fetching summaries for batch 2106 in language en.m
# Fetching summaries for batch 2107 in language en.m
# Fetching summaries for batch 2108 in language en.m
# Fetching summaries for batch 2109 in language en.m
# Fetching summaries for batch 2110 in language en.m
# Fetching summaries for batch 2111 in language en.m
# Fetching summaries for batch 2112 in language en.m
# Fetching summaries for batch 2113 in language en.m
# Fetching summaries for batch 2114 in language en.m
# Fetching summaries for batch 2115 in language en.m
# Fetching summaries for batch 2116 in language en.m
# Fetching summaries for batch 2117 in language en.m
# Fetching summaries for batch 2118 in language en.m
# Fetching summaries for batch 2119 in language en.m
# Fetching summaries for batch 2120 in language en.m
# Fetching summaries for batch 2121 in language en.m
# Fetching summaries for batch 2122 in language en.m
# Fetching summaries for batch 2123 in language en.m
# Fetching summaries for batch 2124 in language en.m
# Fetching summaries for batch 2125 in language en.m
# Fetching summaries for batch 2126 in language en.m
# Fetching summaries for batch 2127 in language en.m
# Fetching summaries for batch 2128 in language en.m
# Fetching summaries for batch 2129 in language en.m
# Fetching summaries for batch 2130 in language en.m
# Fetching summaries for batch 2131 in language en.m
# Fetching summaries for batch 2132 in language en.m
# Fetching summaries for batch 2133 in language en.m
# Fetching summaries for batch 2134 in language en.m
# Fetching summaries for batch 2135 in language en.m
# Fetching summaries for batch 2136 in language en.m
# Fetching summaries for batch 2137 in language en.m
# Fetching summaries for batch 2138 in language en.m
# Fetching summaries for batch 2139 in language en.m
# Fetching summaries for batch 2140 in language en.m
# Fetching summaries for batch 2141 in language en.m
# Fetching summaries for batch 2142 in language en.m
# Fetching summaries for batch 2143 in language en.m
# Fetching summaries for batch 2144 in language en.m
# Fetching summaries for batch 2145 in language en.m
# Fetching summaries for batch 2146 in language en.m
# Fetching summaries for batch 2147 in language en.m
# Fetching summaries for batch 2148 in language en.m
# Fetching summaries for batch 2149 in language en.m
# Fetching summaries for batch 2150 in language en.m
# Fetching summaries for batch 2151 in language en.m
# Fetching summaries for batch 2152 in language en.m
# Fetching summaries for batch 2153 in language en.m
# Fetching summaries for batch 2154 in language en.m
# Fetching summaries for batch 2155 in language en.m
# Fetching summaries for batch 2156 in language en.m
# Fetching summaries for batch 2157 in language en.m
# Fetching summaries for batch 2158 in language en.m
# Fetching summaries for batch 2159 in language en.m
# Fetching summaries for batch 2160 in language en.m
# Fetching summaries for batch 2161 in language en.m
# Fetching summaries for batch 2162 in language en.m
# Fetching summaries for batch 2163 in language en.m
# Fetching summaries for batch 2164 in language en.m
# Fetching summaries for batch 2165 in language en.m
# Fetching summaries for batch 2166 in language en.m
# Fetching summaries for batch 2167 in language en.m
# Fetching summaries for batch 2168 in language en.m
# Fetching summaries for batch 2169 in language en.m
# Fetching summaries for batch 2170 in language en.m
# Fetching summaries for batch 2171 in language en.m
# Fetching summaries for batch 2172 in language en.m
# Fetching summaries for batch 2173 in language en.m
# Fetching summaries for batch 2174 in language en.m
# Fetching summaries for batch 2175 in language en.m
# Fetching summaries for batch 2176 in language en.m
# Fetching summaries for batch 2177 in language en.m
# Fetching summaries for batch 2178 in language en.m
# Fetching summaries for batch 2179 in language en.m
# Fetching summaries for batch 2180 in language en.m
# Fetching summaries for batch 2181 in language en.m
# Fetching summaries for batch 2182 in language en.m
# Fetching summaries for batch 2183 in language en.m
# Fetching summaries for batch 2184 in language en.m
# Fetching summaries for batch 2185 in language en.m
# Fetching summaries for batch 2186 in language en.m
# Fetching summaries for batch 2187 in language en.m
# Fetching summaries for batch 2188 in language en.m
# Fetching summaries for batch 2189 in language en.m
# Fetching summaries for batch 2190 in language en.m
# Fetching summaries for batch 2191 in language en.m
# Fetching summaries for batch 2192 in language en.m
# Fetching summaries for batch 2193 in language en.m
# Fetching summaries for batch 2194 in language en.m
# Fetching summaries for batch 2195 in language en.m
# Fetching summaries for batch 2196 in language en.m
# Fetching summaries for batch 2197 in language en.m
# Fetching summaries for batch 2198 in language en.m
# Fetching summaries for batch 2199 in language en.m
# Fetching summaries for batch 2200 in language en.m
# Fetching summaries for batch 2201 in language en.m
# Fetching summaries for batch 2202 in language en.m
# Fetching summaries for batch 2203 in language en.m
# Fetching summaries for batch 2204 in language en.m
# Fetching summaries for batch 2205 in language en.m
# Fetching summaries for batch 2206 in language en.m
# Fetching summaries for batch 2207 in language en.m
# Fetching summaries for batch 2208 in language en.m
# Fetching summaries for batch 2209 in language en.m
# Fetching summaries for batch 2210 in language en.m
# Fetching summaries for batch 2211 in language en.m
# Fetching summaries for batch 2212 in language en.m
# Fetching summaries for batch 2213 in language en.m
# Fetching summaries for batch 2214 in language en.m
# Fetching summaries for batch 2215 in language en.m
# Fetching summaries for batch 2216 in language en.m
# Fetching summaries for batch 2217 in language en.m
# Fetching summaries for batch 2218 in language en.m
# Fetching summaries for batch 2219 in language en.m
# Fetching summaries for batch 2220 in language en.m
# Fetching summaries for batch 2221 in language en.m
# Fetching summaries for batch 2222 in language en.m
# Fetching summaries for batch 2223 in language en.m
# Fetching summaries for batch 2224 in language en.m
# Fetching summaries for batch 2225 in language en.m
# Fetching summaries for batch 2226 in language en.m
# Fetching summaries for batch 2227 in language en.m
# Fetching summaries for batch 2228 in language en.m
# Fetching summaries for batch 2229 in language en.m
# Fetching summaries for batch 2230 in language en.m
# Fetching summaries for batch 2231 in language en.m
# Fetching summaries for batch 2232 in language en.m
# Fetching summaries for batch 2233 in language en.m
# Fetching summaries for batch 2234 in language en.m
# Fetching summaries for batch 2235 in language en.m
# Fetching summaries for batch 2236 in language en.m
# Fetching summaries for batch 2237 in language en.m
# Fetching summaries for batch 2238 in language en.m
# Fetching summaries for batch 2239 in language en.m
# Fetching summaries for batch 2240 in language en.m
# Fetching summaries for batch 2241 in language en.m
# Fetching summaries for batch 2242 in language en.m
# Fetching summaries for batch 2243 in language en.m
# Fetching summaries for batch 2244 in language en.m
# Fetching summaries for batch 2245 in language en.m
# Fetching summaries for batch 2246 in language en.m
# Fetching summaries for batch 2247 in language en.m
# Fetching summaries for batch 2248 in language en.m
# Fetching summaries for batch 2249 in language en.m
# Fetching summaries for batch 2250 in language en.m
# Fetching summaries for batch 2251 in language en.m
# Fetching summaries for batch 2252 in language en.m
# Fetching summaries for batch 2253 in language en.m
# Fetching summaries for batch 2254 in language en.m
# Fetching summaries for batch 2255 in language en.m
# Fetching summaries for batch 2256 in language en.m
# Fetching summaries for batch 2257 in language en.m
# Fetching summaries for batch 2258 in language en.m
# Fetching summaries for batch 2259 in language en.m
# Fetching summaries for batch 2260 in language en.m
# Fetching summaries for batch 2261 in language en.m
# Fetching summaries for batch 2262 in language en.m
# Fetching summaries for batch 2263 in language en.m
# Fetching summaries for batch 2264 in language en.m
# Fetching summaries for batch 2265 in language en.m
# Fetching summaries for batch 2266 in language en.m
# Fetching summaries for batch 2267 in language en.m
# Fetching summaries for batch 2268 in language en.m
# Fetching summaries for batch 2269 in language en.m
# Fetching summaries for batch 2270 in language en.m
# Fetching summaries for batch 2271 in language en.m
# Fetching summaries for batch 2272 in language en.m
# Fetching summaries for batch 2273 in language en.m
# Fetching summaries for batch 2274 in language en.m
# Fetching summaries for batch 2275 in language en.m
# Fetching summaries for batch 2276 in language en.m
# Fetching summaries for batch 2277 in language en.m
# Fetching summaries for batch 2278 in language en.m
# Fetching summaries for batch 2279 in language en.m
# Fetching summaries for batch 2280 in language en.m
# Fetching summaries for batch 2281 in language en.m
# Fetching summaries for batch 2282 in language en.m
# Fetching summaries for batch 2283 in language en.m
# Fetching summaries for batch 2284 in language en.m
# Fetching summaries for batch 2285 in language en.m
# Fetching summaries for batch 2286 in language en.m
# Fetching summaries for batch 2287 in language en.m
# Fetching summaries for batch 2288 in language en.m
# Fetching summaries for batch 2289 in language en.m
# Fetching summaries for batch 2290 in language en.m
# Fetching summaries for batch 2291 in language en.m
# Fetching summaries for batch 2292 in language en.m
# Fetching summaries for batch 2293 in language en.m
# Fetching summaries for batch 2294 in language en.m
# Fetching summaries for batch 2295 in language en.m
# Fetching summaries for batch 2296 in language en.m
# Fetching summaries for batch 2297 in language en.m
# Fetching summaries for batch 2298 in language en.m
# Fetching summaries for batch 2299 in language en.m
# Fetching summaries for batch 2300 in language en.m
# Fetching summaries for batch 2301 in language en.m
# Fetching summaries for batch 2302 in language en.m
# Fetching summaries for batch 2303 in language en.m
# Fetching summaries for batch 2304 in language en.m
# Fetching summaries for batch 2305 in language en.m
# Fetching summaries for batch 2306 in language en.m
# Fetching summaries for batch 2307 in language en.m
# Fetching summaries for batch 2308 in language en.m
# Fetching summaries for batch 2309 in language en.m
# Fetching summaries for batch 2310 in language en.m
# Fetching summaries for batch 2311 in language en.m
# Fetching summaries for batch 2312 in language en.m
# Fetching summaries for batch 2313 in language en.m
# Fetching summaries for batch 2314 in language en.m
# Fetching summaries for batch 2315 in language en.m
# Fetching summaries for batch 2316 in language en.m
# Fetching summaries for batch 2317 in language en.m
# Fetching summaries for batch 2318 in language en.m
# Fetching summaries for batch 2319 in language en.m
# Fetching summaries for batch 2320 in language en.m
# Fetching summaries for batch 2321 in language en.m
# Fetching summaries for batch 2322 in language en.m
# Fetching summaries for batch 2323 in language en.m
# Fetching summaries for batch 2324 in language en.m
# Fetching summaries for batch 2325 in language en.m
# Fetching summaries for batch 2326 in language en.m
# Fetching summaries for batch 2327 in language en.m
# Fetching summaries for batch 2328 in language en.m
# Fetching summaries for batch 2329 in language en.m
# Fetching summaries for batch 2330 in language en.m
# Fetching summaries for batch 2331 in language en.m
# Fetching summaries for batch 2332 in language en.m
# Fetching summaries for batch 2333 in language en.m
# Fetching summaries for batch 2334 in language en.m
# Fetching summaries for batch 2335 in language en.m
# Fetching summaries for batch 2336 in language en.m
# Fetching summaries for batch 2337 in language en.m
# Fetching summaries for batch 2338 in language en.m
# Fetching summaries for batch 2339 in language en.m
# Fetching summaries for batch 2340 in language en.m
# Fetching summaries for batch 2341 in language en.m
# Fetching summaries for batch 2342 in language en.m
# Fetching summaries for batch 2343 in language en.m
# Fetching summaries for batch 2344 in language en.m
# Fetching summaries for batch 2345 in language en.m
# Fetching summaries for batch 2346 in language en.m
# Fetching summaries for batch 2347 in language en.m
# Fetching summaries for batch 2348 in language en.m
# Fetching summaries for batch 2349 in language en.m
# Fetching summaries for batch 2350 in language en.m
# Fetching summaries for batch 2351 in language en.m
# Fetching summaries for batch 2352 in language en.m
# Fetching summaries for batch 2353 in language en.m
# Fetching summaries for batch 2354 in language en.m
# Fetching summaries for batch 2355 in language en.m
# Fetching summaries for batch 2356 in language en.m
# Fetching summaries for batch 2357 in language en.m
# Fetching summaries for batch 2358 in language en.m
# Fetching summaries for batch 2359 in language en.m
# Fetching summaries for batch 2360 in language en.m
# Fetching summaries for batch 2361 in language en.m
# Fetching summaries for batch 2362 in language en.m
# Fetching summaries for batch 2363 in language en.m
# Fetching summaries for batch 2364 in language en.m
# Fetching summaries for batch 2365 in language en.m
# Fetching summaries for batch 2366 in language en.m
# Fetching summaries for batch 2367 in language en.m
# Fetching summaries for batch 2368 in language en.m
# Fetching summaries for batch 2369 in language en.m
# Fetching summaries for batch 2370 in language en.m
# Fetching summaries for batch 2371 in language en.m
# Fetching summaries for batch 2372 in language en.m
# Fetching summaries for batch 2373 in language en.m
# Fetching summaries for batch 2374 in language en.m
# Fetching summaries for batch 2375 in language en.m
# Fetching summaries for batch 2376 in language en.m
# Fetching summaries for batch 2377 in language en.m
# Fetching summaries for batch 2378 in language en.m
# Fetching summaries for batch 2379 in language en.m
# Fetching summaries for batch 2380 in language en.m
# Fetching summaries for batch 2381 in language en.m
# Fetching summaries for batch 2382 in language en.m
# Fetching summaries for batch 2383 in language en.m
# Fetching summaries for batch 2384 in language en.m
# Fetching summaries for batch 2385 in language en.m
# Fetching summaries for batch 2386 in language en.m
# Fetching summaries for batch 2387 in language en.m
# Fetching summaries for batch 2388 in language en.m
# Fetching summaries for batch 2389 in language en.m
# Fetching summaries for batch 2390 in language en.m
# Fetching summaries for batch 2391 in language en.m
# Fetching summaries for batch 2392 in language en.m
# Fetching summaries for batch 2393 in language en.m
# Fetching summaries for batch 2394 in language en.m
# Fetching summaries for batch 2395 in language en.m
# Fetching summaries for batch 2396 in language en.m
# Fetching summaries for batch 2397 in language en.m
# Fetching summaries for batch 2398 in language en.m

# %%
df_final.info()
